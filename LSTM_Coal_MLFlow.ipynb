# %% [markdown]
# # Importing Libraries

# %%
#D:\\FP2\\all commercial\\all commercial\\coal\\
#!pip install tensorflow

# %%
import numpy as np
import pandas as pd
import os
import math
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense
from nsepy import get_history
from datetime import date
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
# Out:
# 2023-02-25 19:06:45.926468: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
coal_data=pd.read_csv("Total_consumption_coal_Alaska_all_commercial_(total)_monthly.csv")
coal_data=coal_data.rename(columns={'Series ID: ELEC.CONS_TOT.COW-AK-96.M thousand tons':'Coal_Con'})
mean_values = (coal_data['Coal_Con'].shift() + coal_data['Coal_Con'].shift(-1)) / 2

# Replace missing values with the mean of the preceding and following values
coal_data['Coal_Con'].fillna(mean_values, inplace=True)
coal_data['D'] = coal_data['Month'].str.slice(0, 2)
coal_data['M'] = coal_data['Month'].str.slice(3, 5)
coal_data['Y'] = coal_data['Month'].str.slice(6, 10)
coal_data['Date1'] = coal_data['Y']+'-'+coal_data['M']+'-'+coal_data['D']
coal_data['Date'] = pd.to_datetime(coal_data['Date1'])
coal_data3=coal_data.sort_values(['Date'],ascending=True)
coal_data4=coal_data3[['Date','Coal_Con']]
coal_data4
# Out:
#           Date  Coal_Con
# 0   2001-01-01   16.1900
# 1   2001-02-01   29.5000
# 2   2001-03-01   29.6000
# 3   2001-04-01   14.0600
# 4   2001-05-01   13.9700
# ..         ...       ...
# 256 2022-05-01   18.0265
# 257 2022-06-01   23.2220
# 258 2022-07-01   25.6640
# 259 2022-08-01   24.7120
# 260 2022-09-01   23.7600
#
# [261 rows x 2 columns]

# %%
# dataset creation
#coal_data4=coal_data3.copy()
df = coal_data4.set_index("Date")
df['Coal_Con'].plot(style="-")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Create a dataframe with only the Close Stock Price Column
data_target = df.filter(['Coal_Con'])

# Convert the dataframe to a numpy array to train the LSTM model
target = data_target.values

# Splitting the dataset into training and test
# Target Variable: Close stock price value

training_data_len = math.ceil(len(target)* 0.8) # training set has 75% of the data
training_data_len

# Normalizing data before model fitting using MinMaxScaler
# Feature Scaling

sc = MinMaxScaler(feature_range=(0,1))
training_scaled_data = sc.fit_transform(target)
training_scaled_data
# Out:
# array([[0.10994152],
#        [0.3494377 ],
#        [0.35123707],
#        [0.07161493],
#        [0.0699955 ],
#        [0.02159244],
#        [0.28951867],
#        [0.49608637],
#        [0.44264507],
#        [0.16644175],
#        [0.00161943],
#        [0.        ],
#        [0.24107962],
#        [0.17493477],
#        [0.20620783],
#        [0.1868646 ],
#        [0.20665767],
#        [0.10796221],
#        [0.16352677],
#        [0.17957715],
#        [0.25819163],
#        [0.27902834],
#        [0.23863248],
#        [0.28379667],
#        [0.63825461],
#        [0.54472335],
#        [0.568583  ],
#        [0.47717499],
#        [0.46492128],
#        [0.43361224],
#        [0.47681511],
#        [0.44878093],
#        [0.49266757],
#        [0.54522717],
#        [0.58103464],
#        [0.67013945],
#        [0.78191633],
#        [0.65876743],
#        [0.66630679],
#        [0.45099415],
#        [0.36912281],
#        [0.37509672],
#        [0.35847054],
#        [0.36320288],
#        [0.40289699],
#        [0.54076473],
#        [0.67974809],
#        [0.60242915],
#        [0.73043635],
#        [0.6291498 ],
#        [0.62312191],
#        [0.49477283],
#        [0.39843455],
#        [0.35359424],
#        [0.39010346],
#        [0.40851102],
#        [0.36784525],
#        [0.48565002],
#        [0.66018893],
#        [0.67778677],
#        [0.76471435],
#        [0.57140801],
#        [0.67497976],
#        [0.44365272],
#        [0.36995052],
#        [0.33522267],
#        [0.33811966],
#        [0.33459289],
#        [0.34774629],
#        [0.46348178],
#        [0.72500225],
#        [0.69461089],
#        [0.71521368],
#        [0.63382816],
#        [0.72924876],
#        [0.47318039],
#        [0.35015744],
#        [0.22069276],
#        [0.34260009],
#        [0.33601439],
#        [0.42366172],
#        [0.61353126],
#        [0.63476383],
#        [0.75244265],
#        [0.9042735 ],
#        [0.69986505],
#        [0.65475484],
#        [0.53533063],
#        [0.45910931],
#        [0.4588574 ],
#        [0.38592892],
#        [0.32813315],
#        [0.40511021],
#        [0.61392713],
#        [0.63269456],
#        [0.76053981],
#        [0.75661718],
#        [0.65140801],
#        [0.67690508],
#        [0.49106613],
#        [0.3311561 ],
#        [0.28962663],
#        [0.33635628],
#        [0.36413855],
#        [0.40834908],
#        [0.59589744],
#        [0.73993702],
#        [0.78033288],
#        [0.84575798],
#        [0.6385605 ],
#        [0.68088169],
#        [0.52863698],
#        [0.42065677],
#        [0.25991903],
#        [0.18134053],
#        [0.40977058],
#        [0.44525416],
#        [0.56701754],
#        [0.63528565],
#        [0.8671345 ],
#        [0.78733243],
#        [0.72498426],
#        [0.76642375],
#        [0.59874044],
#        [0.51048133],
#        [0.46031489],
#        [0.50380567],
#        [0.42839406],
#        [0.5282771 ],
#        [0.73007647],
#        [0.8251372 ],
#        [0.84825911],
#        [1.        ],
#        [0.75013945],
#        [0.83154296],
#        [0.63238866],
#        [0.50841206],
#        [0.34243815],
#        [0.33842555],
#        [0.46011696],
#        [0.54562303],
#        [0.63129105],
#        [0.85504274],
#        [0.83919028],
#        [0.82619883],
#        [0.72978857],
#        [0.73063428],
#        [0.57389114],
#        [0.5022762 ],
#        [0.42051282],
#        [0.42877193],
#        [0.48415655],
#        [0.52694557],
#        [0.5977148 ],
#        [0.68725146],
#        [0.77777778],
#        [0.24365272],
#        [0.21981107],
#        [0.21793972],
#        [0.16534413],
#        [0.09660819],
#        [0.1025641 ],
#        [0.10474134],
#        [0.13045434],
#        [0.14596491],
#        [0.15048133],
#        [0.16138552],
#        [0.23782276],
#        [0.23694107],
#        [0.16439046],
#        [0.23017544],
#        [0.15622132],
#        [0.09982906],
#        [0.09842555],
#        [0.10083671],
#        [0.15156095],
#        [0.15438596],
#        [0.18731444],
#        [0.20151147],
#        [0.25874944],
#        [0.23928025],
#        [0.21423302],
#        [0.20563203],
#        [0.11118309],
#        [0.11260459],
#        [0.1068466 ],
#        [0.11393612],
#        [0.11735493],
#        [0.12919478],
#        [0.20174539],
#        [0.22389564],
#        [0.27775079],
#        [0.25405308],
#        [0.21005848],
#        [0.25907332],
#        [0.13835358],
#        [0.11031939],
#        [0.10880792],
#        [0.12169141],
#        [0.13538462],
#        [0.13707602],
#        [0.20293297],
#        [0.22927575],
#        [0.23843455],
#        [0.25326136],
#        [0.20131354],
#        [0.20926676],
#        [0.15953216],
#        [0.14135852],
#        [0.09601439],
#        [0.11042735],
#        [0.12282501],
#        [0.13090418],
#        [0.1745749 ],
#        [0.21112011],
#        [0.22261808],
#        [0.26621682],
#        [0.21155196],
#        [0.18726046],
#        [0.1168511 ],
#        [0.1208457 ],
#        [0.08669366],
#        [0.1037157 ],
#        [0.11631129],
#        [0.11602339],
#        [0.15073324],
#        [0.20834908],
#        [0.20989654],
#        [0.20930274],
#        [0.31821862],
#        [0.29948718],
#        [0.21612236],
#        [0.15850652],
#        [0.13443095],
#        [0.04489429],
#        [0.14920378],
#        [0.16926676],
#        [0.24167341],
#        [0.2954206 ],
#        [0.34299595],
#        [0.31951417],
#        [0.32573999],
#        [0.31695906],
#        [0.26794422],
#        [0.11793072],
#        [0.16001799],
#        [0.16318489],
#        [0.22279802],
#        [0.23665317],
#        [0.29581646],
#        [0.41932524],
#        [0.40158345],
#        [0.29239766],
#        [0.18321188],
#        [0.07440396],
#        [0.04950067],
#        [0.14298695],
#        [0.23647323],
#        [0.28041386],
#        [0.26328385],
#        [0.24615385]])

# %%
training_data_len
# Out:
# 209

# %%
# Create a training dataset containing the last 180-day closing price values we want to use to estimate the 181st closing price value.
train_data = training_scaled_data[0:training_data_len , : ]

X_train = []
y_train = []
for i in range(180, len(train_data)):
    X_train.append(train_data[i-180:i, 0])
    y_train.append(train_data[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train) # converting into numpy sequences to train the LSTM model
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print('Number of rows and columns: ', X_train.shape)  #(854 values, 180 time-steps, 1 output)
# Out:
# Number of rows and columns:  (29, 180, 1)

# %%
y_train
# Out:
# array([0.23928025, 0.21423302, 0.20563203, 0.11118309, 0.11260459,
#        0.1068466 , 0.11393612, 0.11735493, 0.12919478, 0.20174539,
#        0.22389564, 0.27775079, 0.25405308, 0.21005848, 0.25907332,
#        0.13835358, 0.11031939, 0.10880792, 0.12169141, 0.13538462,
#        0.13707602, 0.20293297, 0.22927575, 0.23843455, 0.25326136,
#        0.20131354, 0.20926676, 0.15953216, 0.14135852])

# %%
train_data
# Out:
# array([[0.10994152],
#        [0.3494377 ],
#        [0.35123707],
#        [0.07161493],
#        [0.0699955 ],
#        [0.02159244],
#        [0.28951867],
#        [0.49608637],
#        [0.44264507],
#        [0.16644175],
#        [0.00161943],
#        [0.        ],
#        [0.24107962],
#        [0.17493477],
#        [0.20620783],
#        [0.1868646 ],
#        [0.20665767],
#        [0.10796221],
#        [0.16352677],
#        [0.17957715],
#        [0.25819163],
#        [0.27902834],
#        [0.23863248],
#        [0.28379667],
#        [0.63825461],
#        [0.54472335],
#        [0.568583  ],
#        [0.47717499],
#        [0.46492128],
#        [0.43361224],
#        [0.47681511],
#        [0.44878093],
#        [0.49266757],
#        [0.54522717],
#        [0.58103464],
#        [0.67013945],
#        [0.78191633],
#        [0.65876743],
#        [0.66630679],
#        [0.45099415],
#        [0.36912281],
#        [0.37509672],
#        [0.35847054],
#        [0.36320288],
#        [0.40289699],
#        [0.54076473],
#        [0.67974809],
#        [0.60242915],
#        [0.73043635],
#        [0.6291498 ],
#        [0.62312191],
#        [0.49477283],
#        [0.39843455],
#        [0.35359424],
#        [0.39010346],
#        [0.40851102],
#        [0.36784525],
#        [0.48565002],
#        [0.66018893],
#        [0.67778677],
#        [0.76471435],
#        [0.57140801],
#        [0.67497976],
#        [0.44365272],
#        [0.36995052],
#        [0.33522267],
#        [0.33811966],
#        [0.33459289],
#        [0.34774629],
#        [0.46348178],
#        [0.72500225],
#        [0.69461089],
#        [0.71521368],
#        [0.63382816],
#        [0.72924876],
#        [0.47318039],
#        [0.35015744],
#        [0.22069276],
#        [0.34260009],
#        [0.33601439],
#        [0.42366172],
#        [0.61353126],
#        [0.63476383],
#        [0.75244265],
#        [0.9042735 ],
#        [0.69986505],
#        [0.65475484],
#        [0.53533063],
#        [0.45910931],
#        [0.4588574 ],
#        [0.38592892],
#        [0.32813315],
#        [0.40511021],
#        [0.61392713],
#        [0.63269456],
#        [0.76053981],
#        [0.75661718],
#        [0.65140801],
#        [0.67690508],
#        [0.49106613],
#        [0.3311561 ],
#        [0.28962663],
#        [0.33635628],
#        [0.36413855],
#        [0.40834908],
#        [0.59589744],
#        [0.73993702],
#        [0.78033288],
#        [0.84575798],
#        [0.6385605 ],
#        [0.68088169],
#        [0.52863698],
#        [0.42065677],
#        [0.25991903],
#        [0.18134053],
#        [0.40977058],
#        [0.44525416],
#        [0.56701754],
#        [0.63528565],
#        [0.8671345 ],
#        [0.78733243],
#        [0.72498426],
#        [0.76642375],
#        [0.59874044],
#        [0.51048133],
#        [0.46031489],
#        [0.50380567],
#        [0.42839406],
#        [0.5282771 ],
#        [0.73007647],
#        [0.8251372 ],
#        [0.84825911],
#        [1.        ],
#        [0.75013945],
#        [0.83154296],
#        [0.63238866],
#        [0.50841206],
#        [0.34243815],
#        [0.33842555],
#        [0.46011696],
#        [0.54562303],
#        [0.63129105],
#        [0.85504274],
#        [0.83919028],
#        [0.82619883],
#        [0.72978857],
#        [0.73063428],
#        [0.57389114],
#        [0.5022762 ],
#        [0.42051282],
#        [0.42877193],
#        [0.48415655],
#        [0.52694557],
#        [0.5977148 ],
#        [0.68725146],
#        [0.77777778],
#        [0.24365272],
#        [0.21981107],
#        [0.21793972],
#        [0.16534413],
#        [0.09660819],
#        [0.1025641 ],
#        [0.10474134],
#        [0.13045434],
#        [0.14596491],
#        [0.15048133],
#        [0.16138552],
#        [0.23782276],
#        [0.23694107],
#        [0.16439046],
#        [0.23017544],
#        [0.15622132],
#        [0.09982906],
#        [0.09842555],
#        [0.10083671],
#        [0.15156095],
#        [0.15438596],
#        [0.18731444],
#        [0.20151147],
#        [0.25874944],
#        [0.23928025],
#        [0.21423302],
#        [0.20563203],
#        [0.11118309],
#        [0.11260459],
#        [0.1068466 ],
#        [0.11393612],
#        [0.11735493],
#        [0.12919478],
#        [0.20174539],
#        [0.22389564],
#        [0.27775079],
#        [0.25405308],
#        [0.21005848],
#        [0.25907332],
#        [0.13835358],
#        [0.11031939],
#        [0.10880792],
#        [0.12169141],
#        [0.13538462],
#        [0.13707602],
#        [0.20293297],
#        [0.22927575],
#        [0.23843455],
#        [0.25326136],
#        [0.20131354],
#        [0.20926676],
#        [0.15953216],
#        [0.14135852]])

# %%
X_train
# Out:
# array([[[0.10994152],
#         [0.3494377 ],
#         [0.35123707],
#         ...,
#         [0.18731444],
#         [0.20151147],
#         [0.25874944]],
#
#        [[0.3494377 ],
#         [0.35123707],
#         [0.07161493],
#         ...,
#         [0.20151147],
#         [0.25874944],
#         [0.23928025]],
#
#        [[0.35123707],
#         [0.07161493],
#         [0.0699955 ],
#         ...,
#         [0.25874944],
#         [0.23928025],
#         [0.21423302]],
#
#        ...,
#
#        [[0.568583  ],
#         [0.47717499],
#         [0.46492128],
#         ...,
#         [0.23843455],
#         [0.25326136],
#         [0.20131354]],
#
#        [[0.47717499],
#         [0.46492128],
#         [0.43361224],
#         ...,
#         [0.25326136],
#         [0.20131354],
#         [0.20926676]],
#
#        [[0.46492128],
#         [0.43361224],
#         [0.47681511],
#         ...,
#         [0.20131354],
#         [0.20926676],
#         [0.15953216]]])

# %%
y_train
# Out:
# array([0.23928025, 0.21423302, 0.20563203, 0.11118309, 0.11260459,
#        0.1068466 , 0.11393612, 0.11735493, 0.12919478, 0.20174539,
#        0.22389564, 0.27775079, 0.25405308, 0.21005848, 0.25907332,
#        0.13835358, 0.11031939, 0.10880792, 0.12169141, 0.13538462,
#        0.13707602, 0.20293297, 0.22927575, 0.23843455, 0.25326136,
#        0.20131354, 0.20926676, 0.15953216, 0.14135852])

# %%
# We add the LSTM layer and later add a few Dropout layers to prevent overfitting.
# Building a LTSM model with 50 neurons and 4 hidden layers. We add the LSTM layer with the following arguments:
# 50 units which is the dimensionality of the output space
# return_sequences=True which determines whether to return the last output in the output sequence, or the full sequence input_shape as the shape of our training set.
# When defining the Dropout layers, we specify 0.2, meaning that 20% of the layers will be dropped.
# Thereafter, we add the Dense layer that specifies the output of 1 unit.
# After this, we compile our model using the popular adam optimizer and set the loss as the mean_squarred_error.

model = Sequential()

#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))

# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
#model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# 2023-02-25 19:06:59.528470: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
training_data_len
# Out:
# 209

# %%
train_data = training_scaled_data[0:training_data_len  , : ]
train_data
# Out:
# array([[0.10994152],
#        [0.3494377 ],
#        [0.35123707],
#        [0.07161493],
#        [0.0699955 ],
#        [0.02159244],
#        [0.28951867],
#        [0.49608637],
#        [0.44264507],
#        [0.16644175],
#        [0.00161943],
#        [0.        ],
#        [0.24107962],
#        [0.17493477],
#        [0.20620783],
#        [0.1868646 ],
#        [0.20665767],
#        [0.10796221],
#        [0.16352677],
#        [0.17957715],
#        [0.25819163],
#        [0.27902834],
#        [0.23863248],
#        [0.28379667],
#        [0.63825461],
#        [0.54472335],
#        [0.568583  ],
#        [0.47717499],
#        [0.46492128],
#        [0.43361224],
#        [0.47681511],
#        [0.44878093],
#        [0.49266757],
#        [0.54522717],
#        [0.58103464],
#        [0.67013945],
#        [0.78191633],
#        [0.65876743],
#        [0.66630679],
#        [0.45099415],
#        [0.36912281],
#        [0.37509672],
#        [0.35847054],
#        [0.36320288],
#        [0.40289699],
#        [0.54076473],
#        [0.67974809],
#        [0.60242915],
#        [0.73043635],
#        [0.6291498 ],
#        [0.62312191],
#        [0.49477283],
#        [0.39843455],
#        [0.35359424],
#        [0.39010346],
#        [0.40851102],
#        [0.36784525],
#        [0.48565002],
#        [0.66018893],
#        [0.67778677],
#        [0.76471435],
#        [0.57140801],
#        [0.67497976],
#        [0.44365272],
#        [0.36995052],
#        [0.33522267],
#        [0.33811966],
#        [0.33459289],
#        [0.34774629],
#        [0.46348178],
#        [0.72500225],
#        [0.69461089],
#        [0.71521368],
#        [0.63382816],
#        [0.72924876],
#        [0.47318039],
#        [0.35015744],
#        [0.22069276],
#        [0.34260009],
#        [0.33601439],
#        [0.42366172],
#        [0.61353126],
#        [0.63476383],
#        [0.75244265],
#        [0.9042735 ],
#        [0.69986505],
#        [0.65475484],
#        [0.53533063],
#        [0.45910931],
#        [0.4588574 ],
#        [0.38592892],
#        [0.32813315],
#        [0.40511021],
#        [0.61392713],
#        [0.63269456],
#        [0.76053981],
#        [0.75661718],
#        [0.65140801],
#        [0.67690508],
#        [0.49106613],
#        [0.3311561 ],
#        [0.28962663],
#        [0.33635628],
#        [0.36413855],
#        [0.40834908],
#        [0.59589744],
#        [0.73993702],
#        [0.78033288],
#        [0.84575798],
#        [0.6385605 ],
#        [0.68088169],
#        [0.52863698],
#        [0.42065677],
#        [0.25991903],
#        [0.18134053],
#        [0.40977058],
#        [0.44525416],
#        [0.56701754],
#        [0.63528565],
#        [0.8671345 ],
#        [0.78733243],
#        [0.72498426],
#        [0.76642375],
#        [0.59874044],
#        [0.51048133],
#        [0.46031489],
#        [0.50380567],
#        [0.42839406],
#        [0.5282771 ],
#        [0.73007647],
#        [0.8251372 ],
#        [0.84825911],
#        [1.        ],
#        [0.75013945],
#        [0.83154296],
#        [0.63238866],
#        [0.50841206],
#        [0.34243815],
#        [0.33842555],
#        [0.46011696],
#        [0.54562303],
#        [0.63129105],
#        [0.85504274],
#        [0.83919028],
#        [0.82619883],
#        [0.72978857],
#        [0.73063428],
#        [0.57389114],
#        [0.5022762 ],
#        [0.42051282],
#        [0.42877193],
#        [0.48415655],
#        [0.52694557],
#        [0.5977148 ],
#        [0.68725146],
#        [0.77777778],
#        [0.24365272],
#        [0.21981107],
#        [0.21793972],
#        [0.16534413],
#        [0.09660819],
#        [0.1025641 ],
#        [0.10474134],
#        [0.13045434],
#        [0.14596491],
#        [0.15048133],
#        [0.16138552],
#        [0.23782276],
#        [0.23694107],
#        [0.16439046],
#        [0.23017544],
#        [0.15622132],
#        [0.09982906],
#        [0.09842555],
#        [0.10083671],
#        [0.15156095],
#        [0.15438596],
#        [0.18731444],
#        [0.20151147],
#        [0.25874944],
#        [0.23928025],
#        [0.21423302],
#        [0.20563203],
#        [0.11118309],
#        [0.11260459],
#        [0.1068466 ],
#        [0.11393612],
#        [0.11735493],
#        [0.12919478],
#        [0.20174539],
#        [0.22389564],
#        [0.27775079],
#        [0.25405308],
#        [0.21005848],
#        [0.25907332],
#        [0.13835358],
#        [0.11031939],
#        [0.10880792],
#        [0.12169141],
#        [0.13538462],
#        [0.13707602],
#        [0.20293297],
#        [0.22927575],
#        [0.23843455],
#        [0.25326136],
#        [0.20131354],
#        [0.20926676],
#        [0.15953216],
#        [0.14135852]])

# %%
# Getting the predicted stock price
test_data = training_scaled_data[training_data_len - 180: , : ]

#Create the x_test and y_test data sets
X_test = []
y_test =  target[training_data_len : , : ]
for i in range(180,len(test_data)):
    X_test.append(test_data[i-180:i,0])

# Convert x_test to a numpy array
X_test = np.array(X_test)

#Reshape the data into the shape accepted by the LSTM
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
print('Number of rows and columns: ', X_test.shape)
# Out:
# Number of rows and columns:  (52, 180, 1)

# %%
import mlflow
import mlflow.keras

# %%
# Fitting the RNN to the Training set
batch_size = 32
n_epochs = 100

# Set mlflow experiment name


mlflow.set_experiment('forecasting-model-coal')

mlflow.tensorflow.autolog()

mlflow.set_tracking_uri("http://127.0.0.1:5000")

# Train model with mlflow tracking
experiment_name = "forecasting-model-coal"

# Check if experiment exists, if not, create it
try:
    experiment_id = mlflow.get_experiment_by_name(experiment_name).experiment_id
except:
    experiment_id = mlflow.create_experiment(experiment_name)

# Start a new run
with mlflow.start_run(experiment_id=experiment_id,nested=True):
    # Log hyperparameters
    #mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")
    mlflow.set_tag("data scientist", "kb")
    mlflow.set_tag("model", model)
    mlflow.log_param('batch_size', batch_size)
    mlflow.log_param('n_epochs', n_epochs)
    

    #mlflow.log_metric('n_val_samples', len(X_val))

    # Train model
    history = model.fit(X_train, y_train, epochs=n_epochs, batch_size=batch_size,
                        validation_data=(X_test,y_test), verbose=2)
    #model_info = mlflow.tensorflow.log_model(model,artifact_path="model",registered_model_name="LSTM")

    # Log training metrics
    train_loss = history.history['loss'][-1]
    val_loss = history.history['val_loss'][-1]
    mlflow.log_metric('train_loss', train_loss)
    mlflow.log_metric('val_loss', val_loss)

    # Log model
    mlflow.keras.log_model(model,'model')

    # Evaluate model on validation set
    predicted_en = model.predict(X_test)
    predicted_en = sc.inverse_transform(predicted_en)
    #charting outputs
    train = data_target[:training_data_len]
    valid = data_target[training_data_len:]
    valid['Predictions'] = predicted_en
    
    fig = plt.figure(figsize=(10,5))
    plt.title('Model')
    plt.xlabel('Date', fontsize=8)
    plt.ylabel('Coal Consumption', fontsize=12)
    plt.plot(train['Coal_Con'])
    plt.plot(valid[['Coal_Con', 'Predictions']])
    plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
    plt.show()
    
    #MAE
    n=mean_absolute_error(valid.Coal_Con, valid["Predictions"])
    print("Mean Absolute error is",n)
    #MAPE
    k=np.mean(np.abs((valid.Coal_Con - valid["Predictions"]) / valid.Coal_Con)) * 100
    print("MAPE is",k)

    #RMSE
    r=math.sqrt(mean_squared_error(valid.Coal_Con, valid["Predictions"]))
    print("RMSE is",r)
    mlflow.log_param("model", "LSTM")
    mlflow.log_metric("mae", n)
    mlflow.log_metric("mape", k)
    mlflow.log_metric("rmse", r)
    mlflow.log_figure(fig, "my-plot.png")
# Out:
# 2023/02/25 19:10:58 INFO mlflow.tracking.fluent: Experiment with name 'sample-experiment' does not exist. Creating a new experiment.
# 2023/02/25 19:10:58 WARNING mlflow.utils.git_utils: Failed to import Git (the Git executable is probably not on your PATH), so Git SHA is not available. Error: Failed to initialize: Cmd('git') failed due to: exit code(1)
#   cmdline: git version
#   stderr: 'xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun'
# Epoch 1/100
# 1/1 - 9s - loss: 0.0355 - val_loss: 478.8831 - 9s/epoch - 9s/step
# Epoch 2/100
# 1/1 - 1s - loss: 0.0254 - val_loss: 477.3830 - 564ms/epoch - 564ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.0161 - val_loss: 475.4982 - 471ms/epoch - 471ms/step
# Epoch 4/100
# 1/1 - 1s - loss: 0.0085 - val_loss: 472.9445 - 510ms/epoch - 510ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.0040 - val_loss: 470.3945 - 451ms/epoch - 451ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.0087 - val_loss: 470.3810 - 484ms/epoch - 484ms/step
# Epoch 7/100
# 1/1 - 1s - loss: 0.0095 - val_loss: 471.4427 - 511ms/epoch - 511ms/step
# Epoch 8/100
# 1/1 - 1s - loss: 0.0052 - val_loss: 472.6008 - 552ms/epoch - 552ms/step
# Epoch 9/100
# 1/1 - 1s - loss: 0.0032 - val_loss: 473.5288 - 637ms/epoch - 637ms/step
# Epoch 10/100
# 1/1 - 1s - loss: 0.0047 - val_loss: 474.0880 - 559ms/epoch - 559ms/step
# Epoch 11/100
# 1/1 - 1s - loss: 0.0054 - val_loss: 474.2532 - 514ms/epoch - 514ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 0.0056 - val_loss: 474.1309 - 442ms/epoch - 442ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 0.0054 - val_loss: 473.8184 - 455ms/epoch - 455ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 0.0046 - val_loss: 473.3807 - 442ms/epoch - 442ms/step
# Epoch 15/100
# 1/1 - 1s - loss: 0.0043 - val_loss: 472.8815 - 511ms/epoch - 511ms/step
# Epoch 16/100
# 1/1 - 1s - loss: 0.0036 - val_loss: 472.3903 - 504ms/epoch - 504ms/step
# Epoch 17/100
# 1/1 - 1s - loss: 0.0039 - val_loss: 471.9518 - 542ms/epoch - 542ms/step
# Epoch 18/100
# 1/1 - 1s - loss: 0.0035 - val_loss: 471.6618 - 511ms/epoch - 511ms/step
# Epoch 19/100
# 1/1 - 1s - loss: 0.0045 - val_loss: 471.5847 - 520ms/epoch - 520ms/step
# Epoch 20/100
# 1/1 - 1s - loss: 0.0038 - val_loss: 471.6631 - 656ms/epoch - 656ms/step
# Epoch 21/100
# 1/1 - 1s - loss: 0.0032 - val_loss: 471.8558 - 769ms/epoch - 769ms/step
# Epoch 22/100
# 1/1 - 1s - loss: 0.0036 - val_loss: 472.1253 - 858ms/epoch - 858ms/step
# Epoch 23/100
# 1/1 - 1s - loss: 0.0045 - val_loss: 472.4442 - 607ms/epoch - 607ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 0.0040 - val_loss: 472.7286 - 451ms/epoch - 451ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 0.0028 - val_loss: 472.9577 - 489ms/epoch - 489ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 0.0042 - val_loss: 473.0860 - 441ms/epoch - 441ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 0.0044 - val_loss: 473.1276 - 423ms/epoch - 423ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 0.0038 - val_loss: 473.0985 - 442ms/epoch - 442ms/step
# Epoch 29/100
# 1/1 - 1s - loss: 0.0040 - val_loss: 472.9953 - 537ms/epoch - 537ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 0.0038 - val_loss: 472.8481 - 429ms/epoch - 429ms/step
# Epoch 31/100
# 1/1 - 1s - loss: 0.0036 - val_loss: 472.6942 - 572ms/epoch - 572ms/step
# Epoch 32/100
# 1/1 - 1s - loss: 0.0032 - val_loss: 472.5077 - 597ms/epoch - 597ms/step
# Epoch 33/100
# 1/1 - 1s - loss: 0.0036 - val_loss: 472.3492 - 547ms/epoch - 547ms/step
# Epoch 34/100
# 1/1 - 1s - loss: 0.0040 - val_loss: 472.2447 - 570ms/epoch - 570ms/step
# Epoch 35/100
# 1/1 - 1s - loss: 0.0034 - val_loss: 472.1554 - 583ms/epoch - 583ms/step
# Epoch 36/100
# 1/1 - 1s - loss: 0.0034 - val_loss: 472.1101 - 575ms/epoch - 575ms/step
# Epoch 37/100
# 1/1 - 1s - loss: 0.0034 - val_loss: 472.1109 - 552ms/epoch - 552ms/step
# Epoch 38/100
# 1/1 - 1s - loss: 0.0035 - val_loss: 472.1487 - 590ms/epoch - 590ms/step
# Epoch 39/100
# 1/1 - 1s - loss: 0.0032 - val_loss: 472.2023 - 530ms/epoch - 530ms/step
# Epoch 40/100
# 1/1 - 1s - loss: 0.0032 - val_loss: 472.2919 - 560ms/epoch - 560ms/step
# Epoch 41/100
# 1/1 - 1s - loss: 0.0035 - val_loss: 472.3958 - 529ms/epoch - 529ms/step
# Epoch 42/100
# 1/1 - 1s - loss: 0.0029 - val_loss: 472.5020 - 537ms/epoch - 537ms/step
# Epoch 43/100
# 1/1 - 1s - loss: 0.0032 - val_loss: 472.6031 - 533ms/epoch - 533ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 0.0029 - val_loss: 472.6764 - 463ms/epoch - 463ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 0.0035 - val_loss: 472.6917 - 486ms/epoch - 486ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.0035 - val_loss: 472.6922 - 415ms/epoch - 415ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.0033 - val_loss: 472.6556 - 457ms/epoch - 457ms/step
# Epoch 48/100
# 1/1 - 1s - loss: 0.0031 - val_loss: 472.5913 - 654ms/epoch - 654ms/step
# Epoch 49/100
# 1/1 - 1s - loss: 0.0033 - val_loss: 472.5031 - 700ms/epoch - 700ms/step
# Epoch 50/100
# 1/1 - 1s - loss: 0.0039 - val_loss: 472.3887 - 694ms/epoch - 694ms/step
# Epoch 51/100
# 1/1 - 1s - loss: 0.0038 - val_loss: 472.3159 - 641ms/epoch - 641ms/step
# Epoch 52/100
# 1/1 - 1s - loss: 0.0028 - val_loss: 472.2420 - 656ms/epoch - 656ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.0031 - val_loss: 472.1878 - 477ms/epoch - 477ms/step
# Epoch 54/100
# 1/1 - 1s - loss: 0.0033 - val_loss: 472.1871 - 525ms/epoch - 525ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.0039 - val_loss: 472.2598 - 440ms/epoch - 440ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.0029 - val_loss: 472.3354 - 432ms/epoch - 432ms/step
# Epoch 57/100
# 1/1 - 1s - loss: 0.0034 - val_loss: 472.3913 - 589ms/epoch - 589ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.0032 - val_loss: 472.4389 - 423ms/epoch - 423ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.0034 - val_loss: 472.4626 - 442ms/epoch - 442ms/step
# Epoch 60/100
# 1/1 - 1s - loss: 0.0026 - val_loss: 472.4673 - 543ms/epoch - 543ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.0032 - val_loss: 472.4643 - 433ms/epoch - 433ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.0035 - val_loss: 472.4397 - 422ms/epoch - 422ms/step
# Epoch 63/100
# 1/1 - 1s - loss: 0.0035 - val_loss: 472.4212 - 515ms/epoch - 515ms/step
# Epoch 64/100
# 1/1 - 1s - loss: 0.0032 - val_loss: 472.3919 - 558ms/epoch - 558ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.0029 - val_loss: 472.3447 - 497ms/epoch - 497ms/step
# Epoch 66/100
# 1/1 - 1s - loss: 0.0032 - val_loss: 472.3137 - 540ms/epoch - 540ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.0040 - val_loss: 472.3010 - 462ms/epoch - 462ms/step
# Epoch 68/100
# 1/1 - 1s - loss: 0.0029 - val_loss: 472.3076 - 581ms/epoch - 581ms/step
# Epoch 69/100
# 1/1 - 1s - loss: 0.0028 - val_loss: 472.3102 - 563ms/epoch - 563ms/step
# Epoch 70/100
# 1/1 - 1s - loss: 0.0033 - val_loss: 472.3576 - 575ms/epoch - 575ms/step
# Epoch 71/100
# 1/1 - 1s - loss: 0.0028 - val_loss: 472.4189 - 539ms/epoch - 539ms/step
# Epoch 72/100
# 1/1 - 1s - loss: 0.0035 - val_loss: 472.4671 - 507ms/epoch - 507ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.0031 - val_loss: 472.4957 - 384ms/epoch - 384ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.0033 - val_loss: 472.4954 - 393ms/epoch - 393ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.0030 - val_loss: 472.5052 - 480ms/epoch - 480ms/step
# Epoch 76/100
# 1/1 - 1s - loss: 0.0031 - val_loss: 472.4751 - 548ms/epoch - 548ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.0032 - val_loss: 472.4230 - 483ms/epoch - 483ms/step
# Epoch 78/100
# 1/1 - 1s - loss: 0.0033 - val_loss: 472.3868 - 521ms/epoch - 521ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.0029 - val_loss: 472.3392 - 481ms/epoch - 481ms/step
# Epoch 80/100
# 1/1 - 1s - loss: 0.0030 - val_loss: 472.2809 - 639ms/epoch - 639ms/step
# Epoch 81/100
# 1/1 - 1s - loss: 0.0033 - val_loss: 472.3007 - 548ms/epoch - 548ms/step
# Epoch 82/100
# 1/1 - 1s - loss: 0.0034 - val_loss: 472.3288 - 525ms/epoch - 525ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.0036 - val_loss: 472.3620 - 498ms/epoch - 498ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.0035 - val_loss: 472.3968 - 406ms/epoch - 406ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.0035 - val_loss: 472.4435 - 409ms/epoch - 409ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.0029 - val_loss: 472.5052 - 415ms/epoch - 415ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.0037 - val_loss: 472.5763 - 418ms/epoch - 418ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.0031 - val_loss: 472.6076 - 397ms/epoch - 397ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.0035 - val_loss: 472.5760 - 416ms/epoch - 416ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.0030 - val_loss: 472.4781 - 439ms/epoch - 439ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.0039 - val_loss: 472.3694 - 414ms/epoch - 414ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.0036 - val_loss: 472.2547 - 418ms/epoch - 418ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.0036 - val_loss: 472.2025 - 403ms/epoch - 403ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.0031 - val_loss: 472.1433 - 416ms/epoch - 416ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.0032 - val_loss: 472.1227 - 434ms/epoch - 434ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.0034 - val_loss: 472.1553 - 394ms/epoch - 394ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.0031 - val_loss: 472.1925 - 419ms/epoch - 419ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.0034 - val_loss: 472.2354 - 417ms/epoch - 417ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.0034 - val_loss: 472.2628 - 409ms/epoch - 409ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.0030 - val_loss: 472.2694 - 421ms/epoch - 421ms/step
# 1/1 [==============================] - 1s 1s/step
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /var/folders/j9/qhmtvh7x7078vxjxd4t6fnh80000gn/T/tmpu_t1r5ft/model/data/model/assets
# INFO:tensorflow:Assets written to: /var/folders/j9/qhmtvh7x7078vxjxd4t6fnh80000gn/T/tmpu_t1r5ft/model/data/model/assets
# 2023/02/25 19:12:26 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/nikhileshwaravs/opt/anaconda3/lib/python3.9/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils."
# 2023/02/25 19:12:26 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /var/folders/j9/qhmtvh7x7078vxjxd4t6fnh80000gn/T/tmpnr_iycbs/model/data/model/assets
# INFO:tensorflow:Assets written to: /var/folders/j9/qhmtvh7x7078vxjxd4t6fnh80000gn/T/tmpnr_iycbs/model/data/model/assets
# 2/2 [==============================] - 0s 60ms/step
# /var/folders/j9/qhmtvh7x7078vxjxd4t6fnh80000gn/T/ipykernel_13994/4280919061.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predicted_en
# Mean Absolute error is 4.055123294536885
# MAPE is 19.20717192133259
# RMSE is 4.925258653973049

# %%
#charting outputs
train = data_target[:training_data_len]
valid = data_target[training_data_len:]
valid['Predictions'] = predicted_en
plt.figure(figsize=(10,5))
plt.title('Model')
plt.xlabel('Date', fontsize=8)
plt.ylabel('Coal Consumption', fontsize=12)
plt.plot(train['Coal_Con'])
plt.plot(valid[['Coal_Con', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# /var/folders/j9/qhmtvh7x7078vxjxd4t6fnh80000gn/T/ipykernel_8923/797815844.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predicted_en

# %%
#output data
valid
# Out:
#             Coal_Con  Predictions
# Date
# 2018-06-01   15.4160    20.376469
# 2018-07-01   16.2170    20.391960
# 2018-08-01   16.9060    20.409624
# 2018-09-01   17.3550    20.424898
# 2018-10-01   19.7820    20.433506
# 2018-11-01   21.8130    20.432325
# 2018-12-01   22.4520    20.420347
# 2019-01-01   24.8750    20.399130
# 2019-02-01   21.8370    20.372259
# 2019-03-01   20.4870    20.345058
# 2019-04-01   16.5740    20.322628
# 2019-05-01   16.7960    20.308487
# 2019-06-01   14.8980    20.303165
# 2019-07-01   15.8440    20.304672
# 2019-08-01   16.5440    20.308981
# 2019-09-01   16.5280    20.311392
# 2019-10-01   18.4570    20.307806
# 2019-11-01   21.6590    20.295309
# 2019-12-01   21.7450    20.272911
# 2020-01-01   21.7120    20.242300
# 2020-02-01   27.7650    20.207222
# 2020-03-01   26.7240    20.172371
# 2020-04-01   22.0910    20.144115
# 2020-05-01   18.8890    20.129219
# 2020-06-01   17.5510    20.132277
# 2020-07-01   12.5750    20.154110
# 2020-08-01   18.3720    20.191797
# 2020-09-01   19.4870    20.238478
# 2020-10-01   23.5110    20.286613
# 2020-11-01   26.4980    20.330051
# 2020-12-01   29.1420    20.365860
# 2021-01-01   27.8370    20.394995
# 2021-02-01   28.1830    20.421982
# 2021-03-01   27.6950    20.452881
# 2021-04-01   24.9710    20.493658
# 2021-05-01   16.6340    20.548904
# 2021-06-01   18.9730    20.620474
# 2021-07-01   19.1490    20.705189
# 2021-08-01   22.4620    20.796457
# 2021-09-01   23.2320    20.886257
# 2021-10-01   26.5200    20.967756
# 2021-11-01   33.3840    21.036503
# 2021-12-01   32.3980    21.091389
# 2022-01-01   26.3300    21.136066
# 2022-02-01   20.2620    21.177326
# 2022-03-01   14.2150    21.221336
# 2022-04-01   12.8310    21.270439
# 2022-05-01   18.0265    21.321459
# 2022-06-01   23.2220    21.366737
# 2022-07-01   25.6640    21.398008
# 2022-08-01   24.7120    21.410088
# 2022-09-01   23.7600    21.402369

# %%
train
# Out:
#             Coal_Con
# Date
# 2001-01-01    16.190
# 2001-02-01    29.500
# 2001-03-01    29.600
# 2001-04-01    14.060
# 2001-05-01    13.970
# ...              ...
# 2018-01-01    24.155
# 2018-02-01    21.268
# 2018-03-01    21.710
# 2018-04-01    18.946
# 2018-05-01    17.936
#
# [209 rows x 1 columns]
