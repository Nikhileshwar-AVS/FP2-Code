# %%
import numpy as np
import pandas as pd
import os
import math
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense
from nsepy import get_history
from datetime import date
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
#ptl_data=pd.read_csv("D:\\FP2\\all commercial\\all commercial\\natural gas\\Total_consumption_natural_gas_Alaska_all_commercial_(total)_monthly.csv")
ptl_data=pd.read_csv("Total_consumption_petroleum_liquids_Alaska_all_commercial_(total)_monthly.csv")
ptl_data=ptl_data.rename(columns={'Series ID: ELEC.CONS_TOT.PEL-AK-96.M thousand barrels':'ptl_Con'})
mean_values = (ptl_data['ptl_Con'].shift() + ptl_data['ptl_Con'].shift(-1)) / 2

# Replace missing values with the mean of the preceding and following values
ptl_data['ptl_Con'].fillna(mean_values, inplace=True)
ptl_data['D'] = ptl_data['Month'].str.slice(0, 2)
ptl_data['M'] = ptl_data['Month'].str.slice(3, 5)
ptl_data['Y'] = ptl_data['Month'].str.slice(6, 10)
ptl_data['Date1'] = ptl_data['Y']+'-'+ptl_data['M']+'-'+ptl_data['D']
ptl_data['Date'] = pd.to_datetime(ptl_data['Date1'])
ptl_data3=ptl_data.sort_values(['Date'],ascending=True)
ptl_data4=ptl_data3[['Date','ptl_Con']]
ptl_data4
# Out:
#           Date  ptl_Con
# 0   2001-01-01    1.590
# 1   2001-02-01    2.890
# 2   2001-03-01    2.910
# 3   2001-04-01    1.380
# 4   2001-05-01    1.370
# ..         ...      ...
# 256 2022-05-01    6.962
# 257 2022-06-01      NaN
# 258 2022-07-01      NaN
# 259 2022-08-01      NaN
# 260 2022-09-01      NaN
#
# [261 rows x 2 columns]

# %%
# dataset creation
#coal_data4=coal_data3.copy()
df = ptl_data4.set_index("Date")
df=df.fillna(df.ptl_Con.mean())
print(df)
df['ptl_Con'].plot(style="-")
# Out:
#              ptl_Con
# Date
# 2001-01-01  1.590000
# 2001-02-01  2.890000
# 2001-03-01  2.910000
# 2001-04-01  1.380000
# 2001-05-01  1.370000
# ...              ...
# 2022-05-01  6.962000
# 2022-06-01  2.384234
# 2022-07-01  2.384234
# 2022-08-01  2.384234
# 2022-09-01  2.384234
#
# [261 rows x 1 columns]
# <AxesSubplot:xlabel='Date'>

# %%
# Create a dataframe with only the Close Stock Price Column
data_target = df.filter(['ptl_Con'])

# Convert the dataframe to a numpy array to train the LSTM model
target = data_target.values

# Splitting the dataset into training and test
# Target Variable: Close stock price value

training_data_len = math.ceil(len(target)* 0.8) # training set has 75% of the data
training_data_len

# Normalizing data before model fitting using MinMaxScaler
# Feature Scaling

sc = MinMaxScaler(feature_range=(0,1))
training_scaled_data = sc.fit_transform(target)
training_scaled_data
# Out:
# array([[9.88266299e-02],
#        [1.80397816e-01],
#        [1.81652758e-01],
#        [8.56497459e-02],
#        [8.50222752e-02],
#        [6.80805672e-02],
#        [1.59691284e-01],
#        [2.31222940e-01],
#        [2.12398820e-01],
#        [1.17650750e-01],
#        [6.11783899e-02],
#        [6.11783899e-02],
#        [2.70188869e-01],
#        [2.27646358e-01],
#        [2.47850913e-01],
#        [2.35677982e-01],
#        [2.48227395e-01],
#        [1.85417582e-01],
#        [2.22814833e-01],
#        [2.32728870e-01],
#        [2.80918617e-01],
#        [2.94283742e-01],
#        [2.68620192e-01],
#        [2.98362302e-01],
#        [1.69354333e-01],
#        [1.49902742e-01],
#        [1.54859760e-01],
#        [1.35847399e-01],
#        [1.33337516e-01],
#        [1.26811822e-01],
#        [1.35784652e-01],
#        [1.29949175e-01],
#        [1.39110247e-01],
#        [1.50028236e-01],
#        [1.57432390e-01],
#        [1.75942775e-01],
#        [3.86390161e-01],
#        [2.74932547e-01],
#        [2.14723599e-01],
#        [1.61184037e-01],
#        [2.83087783e-01],
#        [2.30573508e-01],
#        [6.77229090e-02],
#        [1.67136224e-01],
#        [1.95272009e-01],
#        [1.64701638e-01],
#        [1.94781326e-01],
#        [2.91671582e-01],
#        [4.51312041e-01],
#        [3.18475246e-01],
#        [2.11601305e-01],
#        [1.57463764e-01],
#        [3.90562841e-01],
#        [1.68884985e-01],
#        [1.36747820e-01],
#        [6.40754220e-02],
#        [1.11051641e-01],
#        [8.21597540e-02],
#        [2.19322959e-01],
#        [2.61788919e-01],
#        [3.71282550e-01],
#        [2.32506118e-01],
#        [2.98940202e-01],
#        [1.27758675e-01],
#        [2.00380247e-01],
#        [1.11535421e-01],
#        [4.59691284e-02],
#        [4.97860325e-02],
#        [3.10265420e-02],
#        [4.08426931e-02],
#        [2.41725544e-01],
#        [2.38334693e-01],
#        [3.11790174e-01],
#        [2.71067328e-01],
#        [2.97107360e-01],
#        [5.42134655e-02],
#        [3.33939888e-01],
#        [2.86691347e-01],
#        [1.46451653e-01],
#        [4.11620757e-02],
#        [2.06437849e-02],
#        [3.83384577e-02],
#        [5.40879714e-02],
#        [2.06375102e-01],
#        [2.82612788e-01],
#        [2.50047060e-01],
#        [3.46363807e-02],
#        [7.47945034e-02],
#        [1.59252055e-01],
#        [8.15711865e-03],
#        [2.57262973e-03],
#        [2.10830144e-02],
#        [2.69812386e-03],
#        [4.48014055e-02],
#        [2.28650311e-01],
#        [3.69705716e-01],
#        [4.31386083e-01],
#        [3.39838113e-01],
#        [2.39819288e-01],
#        [8.57752400e-02],
#        [2.54753090e-02],
#        [2.32164146e-02],
#        [1.42498588e-01],
#        [1.73495639e-01],
#        [1.89496141e-02],
#        [2.22752086e-02],
#        [2.05245655e-01],
#        [2.85248165e-01],
#        [2.79475435e-01],
#        [1.03532660e-01],
#        [1.07924955e-02],
#        [8.48967811e-02],
#        [3.02817343e-01],
#        [2.30846458e-01],
#        [8.64027107e-02],
#        [4.21660287e-02],
#        [6.21195959e-03],
#        [2.25889440e-02],
#        [8.68419401e-02],
#        [3.57156303e-01],
#        [2.06877078e-01],
#        [1.79331116e-01],
#        [5.47781891e-02],
#        [1.81966493e-03],
#        [3.13735333e-04],
#        [1.25494133e-04],
#        [3.13735333e-04],
#        [1.14199661e-02],
#        [1.51220430e-02],
#        [5.70998306e-03],
#        [2.09763444e-01],
#        [7.45435151e-02],
#        [4.82524942e-01],
#        [1.00583548e-01],
#        [4.28562465e-02],
#        [1.54985254e-02],
#        [5.80410366e-02],
#        [1.79456610e-02],
#        [2.65420092e-02],
#        [5.79155424e-02],
#        [7.15316559e-02],
#        [2.03300496e-02],
#        [2.61153291e-01],
#        [4.77442430e-01],
#        [1.04787601e-01],
#        [1.70232792e-01],
#        [9.01675347e-02],
#        [2.44086089e-02],
#        [3.13672586e-01],
#        [7.40415386e-03],
#        [9.09832465e-03],
#        [3.41971513e-02],
#        [3.38834160e-03],
#        [1.29886428e-02],
#        [1.96963042e-01],
#        [2.44462571e-01],
#        [7.65514212e-02],
#        [9.58147707e-02],
#        [8.53987576e-02],
#        [6.56961787e-02],
#        [2.30030746e-01],
#        [1.01211018e-01],
#        [2.45968501e-02],
#        [2.50988266e-03],
#        [4.39229466e-04],
#        [2.92401330e-02],
#        [2.45968501e-02],
#        [8.36418397e-02],
#        [4.18962164e-01],
#        [2.89075736e-01],
#        [7.01512204e-02],
#        [9.04185229e-02],
#        [1.94892389e-01],
#        [1.61887432e-02],
#        [1.00395307e-03],
#        [9.28656585e-03],
#        [0.00000000e+00],
#        [7.09041852e-03],
#        [2.23128569e-01],
#        [2.76463575e-01],
#        [1.59314802e-01],
#        [1.44130012e-01],
#        [1.22231286e-01],
#        [6.95237498e-02],
#        [0.00000000e+00],
#        [1.65024785e-02],
#        [5.01976533e-04],
#        [6.40020079e-03],
#        [4.58053586e-03],
#        [5.12016063e-02],
#        [2.47223442e-02],
#        [2.91397377e-01],
#        [3.69642969e-01],
#        [2.31411182e-01],
#        [3.25908264e-01],
#        [1.25494133e-04],
#        [1.16835038e-01],
#        [4.39229466e-04],
#        [2.50988266e-04],
#        [3.07460626e-03],
#        [6.90217732e-04],
#        [4.03463638e-02],
#        [2.61404279e-01],
#        [2.20555939e-01],
#        [4.33456736e-01],
#        [3.05452720e-01],
#        [2.03049507e-01],
#        [3.60795633e-02],
#        [1.56867666e-03],
#        [9.41205999e-04],
#        [5.01976533e-03],
#        [2.14594968e-02],
#        [2.59145385e-02],
#        [7.23473678e-02],
#        [2.94534731e-01],
#        [5.48283868e-01],
#        [3.68199787e-01],
#        [2.36179959e-01],
#        [1.99221936e-01],
#        [3.88843572e-01],
#        [9.65677355e-02],
#        [4.48014055e-02],
#        [2.35301500e-02],
#        [6.59471670e-02],
#        [3.99698814e-02],
#        [2.26767899e-01],
#        [5.61711740e-01],
#        [1.49902742e-01],
#        [3.77109870e-01],
#        [1.44318253e-03],
#        [1.63142373e-03],
#        [1.38043546e-03],
#        [1.06670013e-03],
#        [1.56867666e-03],
#        [3.01374161e-01],
#        [3.59101462e-01],
#        [2.25889440e-03],
#        [1.50592960e-03],
#        [1.12944720e-03],
#        [1.06670013e-03],
#        [2.25889440e-03],
#        [2.50988266e-03],
#        [2.63537680e-03],
#        [2.63537680e-03],
#        [2.72196775e-01],
#        [1.63142373e-03],
#        [1.56867666e-03],
#        [2.50988266e-03],
#        [3.73345046e-02],
#        [3.32559453e-03],
#        [2.57262973e-03],
#        [3.34253624e-01],
#        [1.00000000e+00],
#        [1.34529711e-01],
#        [7.95695551e-01],
#        [6.34874820e-01],
#        [4.35903871e-01],
#        [1.48662464e-01],
#        [1.48662464e-01],
#        [1.48662464e-01],
#        [1.48662464e-01]])

# %%
# Create a training dataset containing the last 180-day closing price values we want to use to estimate the 181st closing price value.
train_data = training_scaled_data[0:training_data_len  , : ]

X_train = []
y_train = []
for i in range(80, len(train_data)):
    X_train.append(train_data[i-80:i, 0])
    y_train.append(train_data[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train) # converting into numpy sequences to train the LSTM model
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print('Number of rows and columns: ', X_train.shape)  #(854 values, 180 time-steps, 1 output)
# Out:
# Number of rows and columns:  (129, 80, 1)

# %%
# We add the LSTM layer and later add a few Dropout layers to prevent overfitting.
# Building a LTSM model with 50 neurons and 4 hidden layers. We add the LSTM layer with the following arguments:
# 50 units which is the dimensionality of the output space
# return_sequences=True which determines whether to return the last output in the output sequence, or the full sequence input_shape as the shape of our training set.
# When defining the Dropout layers, we specify 0.2, meaning that 20% of the layers will be dropped.
# Thereafter, we add the Dense layer that specifies the output of 1 unit.
# After this, we compile our model using the popular adam optimizer and set the loss as the mean_squarred_error.

model = Sequential()

#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))

# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
# Out:
# 2023-02-25 13:37:08.112006: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Getting the predicted stock price
test_data = training_scaled_data[training_data_len - 80: , : ]

#Create the x_test and y_test data sets
X_test = []
y_test =  target[training_data_len : , : ]
for i in range(80,len(test_data)):
    X_test.append(test_data[i-80:i,0])

# Convert x_test to a numpy array
X_test = np.array(X_test)

#Reshape the data into the shape accepted by the LSTM
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
print('Number of rows and columns: ', X_test.shape)
# Out:
# Number of rows and columns:  (52, 80, 1)

# %%
import mlflow
import mlflow.keras

# %%
# Fitting the RNN to the Training set
batch_size = 32
n_epochs = 100

# Set mlflow experiment name


mlflow.set_experiment('forecasting-model-petroluem-liquid')

mlflow.tensorflow.autolog()

mlflow.set_tracking_uri("http://127.0.0.1:5000")

# Train model with mlflow tracking
experiment_name = "forecasting-model-petroluem-liquid"

# Check if experiment exists, if not, create it
try:
    experiment_id = mlflow.get_experiment_by_name(experiment_name).experiment_id
except:
    experiment_id = mlflow.create_experiment(experiment_name)

# Start a new run
with mlflow.start_run(experiment_id=experiment_id,nested=True):
    # Log hyperparameters
    #mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")
    mlflow.set_tag("data scientist", "kb")
    mlflow.set_tag("model", model)
    mlflow.log_param('batch_size', batch_size)
    mlflow.log_param('n_epochs', n_epochs)
    

    #mlflow.log_metric('n_val_samples', len(X_val))

    # Train model
    history = model.fit(X_train, y_train, epochs=n_epochs, batch_size=batch_size,
                        validation_data=(X_test,y_test), verbose=2)
    #model_info = mlflow.tensorflow.log_model(model,artifact_path="model",registered_model_name="LSTM")

    # Log training metrics
    train_loss = history.history['loss'][-1]
    val_loss = history.history['val_loss'][-1]
    mlflow.log_metric('train_loss', train_loss)
    mlflow.log_metric('val_loss', val_loss)

    # Log model
    mlflow.keras.log_model(model,'model')

    # Evaluate model on validation set
    predicted_en = model.predict(X_test)
    predicted_en = sc.inverse_transform(predicted_en)
    #charting outputs
    train = data_target[:training_data_len]
    valid = data_target[training_data_len:]
    valid['Predictions'] = predicted_en
    
    fig = plt.figure(figsize=(10,5))

    plt.title('Model')
    plt.xlabel('Date', fontsize=8)
    plt.ylabel('Petroleum liquid Consumption', fontsize=12)
    plt.plot(train['ptl_Con'])
    plt.plot(valid[['ptl_Con', 'Predictions']])
    plt.legend(['Train', 'Val', 'Predictions'], loc='upper right')
    plt.show()
    
    #MAE
    n=mean_absolute_error(valid.ptl_Con, valid["Predictions"])
    print("Mean Absolute error is",n)
    #MAPE
    k=np.mean(np.abs((valid.ptl_Con - valid["Predictions"]) / valid.ptl_Con)) * 100
    print("MAPE is",k)

    #RMSE
    r=math.sqrt(mean_squared_error(valid.ptl_Con, valid["Predictions"]))
    print("RMSE is",r)
    mlflow.log_param("model", "LSTM")
    mlflow.log_metric("mae", n)
    mlflow.log_metric("mape", k)
    mlflow.log_metric("rmse", r)
    mlflow.log_figure(fig, "my-plot.png")
# Out:
# 2023/02/25 13:37:32 WARNING mlflow.utils.git_utils: Failed to import Git (the Git executable is probably not on your PATH), so Git SHA is not available. Error: Failed to initialize: Cmd('git') failed due to: exit code(1)
#   cmdline: git version
#   stderr: 'xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun'
# Epoch 1/100
# 5/5 - 7s - loss: 0.0221 - val_loss: 18.9405 - 7s/epoch - 1s/step
# Epoch 2/100
# 5/5 - 1s - loss: 0.0191 - val_loss: 19.5727 - 604ms/epoch - 121ms/step
# Epoch 3/100
# 5/5 - 1s - loss: 0.0188 - val_loss: 19.6116 - 571ms/epoch - 114ms/step
# Epoch 4/100
# 5/5 - 1s - loss: 0.0175 - val_loss: 19.3851 - 571ms/epoch - 114ms/step
# Epoch 5/100
# 5/5 - 1s - loss: 0.0160 - val_loss: 19.2867 - 568ms/epoch - 114ms/step
# Epoch 6/100
# 5/5 - 1s - loss: 0.0165 - val_loss: 19.2540 - 602ms/epoch - 120ms/step
# Epoch 7/100
# 5/5 - 1s - loss: 0.0161 - val_loss: 19.4366 - 580ms/epoch - 116ms/step
# Epoch 8/100
# 5/5 - 1s - loss: 0.0165 - val_loss: 19.4782 - 866ms/epoch - 173ms/step
# Epoch 9/100
# 5/5 - 1s - loss: 0.0163 - val_loss: 19.4365 - 747ms/epoch - 149ms/step
# Epoch 10/100
# 5/5 - 1s - loss: 0.0162 - val_loss: 19.3486 - 726ms/epoch - 145ms/step
# Epoch 11/100
# 5/5 - 1s - loss: 0.0156 - val_loss: 19.3668 - 572ms/epoch - 114ms/step
# Epoch 12/100
# 5/5 - 1s - loss: 0.0159 - val_loss: 19.3736 - 580ms/epoch - 116ms/step
# Epoch 13/100
# 5/5 - 1s - loss: 0.0157 - val_loss: 19.3322 - 570ms/epoch - 114ms/step
# Epoch 14/100
# 5/5 - 1s - loss: 0.0156 - val_loss: 19.2625 - 568ms/epoch - 114ms/step
# Epoch 15/100
# 5/5 - 1s - loss: 0.0155 - val_loss: 19.3744 - 566ms/epoch - 113ms/step
# Epoch 16/100
# 5/5 - 1s - loss: 0.0160 - val_loss: 19.4792 - 564ms/epoch - 113ms/step
# Epoch 17/100
# 5/5 - 1s - loss: 0.0166 - val_loss: 19.4880 - 571ms/epoch - 114ms/step
# Epoch 18/100
# 5/5 - 1s - loss: 0.0164 - val_loss: 19.3551 - 565ms/epoch - 113ms/step
# Epoch 19/100
# 5/5 - 1s - loss: 0.0158 - val_loss: 19.3761 - 593ms/epoch - 119ms/step
# Epoch 20/100
# 5/5 - 1s - loss: 0.0156 - val_loss: 19.3843 - 577ms/epoch - 115ms/step
# Epoch 21/100
# 5/5 - 1s - loss: 0.0153 - val_loss: 19.3162 - 568ms/epoch - 114ms/step
# Epoch 22/100
# 5/5 - 1s - loss: 0.0158 - val_loss: 19.3706 - 561ms/epoch - 112ms/step
# Epoch 23/100
# 5/5 - 1s - loss: 0.0158 - val_loss: 19.4727 - 567ms/epoch - 113ms/step
# Epoch 24/100
# 5/5 - 1s - loss: 0.0162 - val_loss: 19.3779 - 924ms/epoch - 185ms/step
# Epoch 25/100
# 5/5 - 1s - loss: 0.0154 - val_loss: 19.3673 - 578ms/epoch - 116ms/step
# Epoch 26/100
# 5/5 - 1s - loss: 0.0163 - val_loss: 19.3697 - 701ms/epoch - 140ms/step
# Epoch 27/100
# 5/5 - 1s - loss: 0.0157 - val_loss: 19.4161 - 794ms/epoch - 159ms/step
# Epoch 28/100
# 5/5 - 1s - loss: 0.0160 - val_loss: 19.4201 - 713ms/epoch - 143ms/step
# Epoch 29/100
# 5/5 - 1s - loss: 0.0158 - val_loss: 19.4215 - 569ms/epoch - 114ms/step
# Epoch 30/100
# 5/5 - 1s - loss: 0.0158 - val_loss: 19.3677 - 584ms/epoch - 117ms/step
# Epoch 31/100
# 5/5 - 1s - loss: 0.0168 - val_loss: 19.2274 - 603ms/epoch - 121ms/step
# Epoch 32/100
# 5/5 - 1s - loss: 0.0160 - val_loss: 19.3771 - 627ms/epoch - 125ms/step
# Epoch 33/100
# 5/5 - 1s - loss: 0.0166 - val_loss: 19.5428 - 801ms/epoch - 160ms/step
# Epoch 34/100
# 5/5 - 1s - loss: 0.0169 - val_loss: 19.4559 - 1s/epoch - 214ms/step
# Epoch 35/100
# 5/5 - 1s - loss: 0.0157 - val_loss: 19.4078 - 880ms/epoch - 176ms/step
# Epoch 36/100
# 5/5 - 1s - loss: 0.0159 - val_loss: 19.3832 - 657ms/epoch - 131ms/step
# Epoch 37/100
# 5/5 - 1s - loss: 0.0157 - val_loss: 19.4199 - 576ms/epoch - 115ms/step
# Epoch 38/100
# 5/5 - 1s - loss: 0.0154 - val_loss: 19.3277 - 575ms/epoch - 115ms/step
# Epoch 39/100
# 5/5 - 1s - loss: 0.0151 - val_loss: 19.3491 - 572ms/epoch - 114ms/step
# Epoch 40/100
# 5/5 - 1s - loss: 0.0152 - val_loss: 19.4363 - 567ms/epoch - 113ms/step
# Epoch 41/100
# 5/5 - 1s - loss: 0.0154 - val_loss: 19.4655 - 568ms/epoch - 114ms/step
# Epoch 42/100
# 5/5 - 1s - loss: 0.0158 - val_loss: 19.4729 - 573ms/epoch - 115ms/step
# Epoch 43/100
# 5/5 - 1s - loss: 0.0158 - val_loss: 19.4366 - 580ms/epoch - 116ms/step
# Epoch 44/100
# 5/5 - 1s - loss: 0.0157 - val_loss: 19.3880 - 573ms/epoch - 115ms/step
# Epoch 45/100
# 5/5 - 1s - loss: 0.0150 - val_loss: 19.2629 - 566ms/epoch - 113ms/step
# Epoch 46/100
# 5/5 - 1s - loss: 0.0155 - val_loss: 19.3111 - 573ms/epoch - 115ms/step
# Epoch 47/100
# 5/5 - 1s - loss: 0.0152 - val_loss: 19.4257 - 573ms/epoch - 115ms/step
# Epoch 48/100
# 5/5 - 1s - loss: 0.0167 - val_loss: 19.4984 - 568ms/epoch - 114ms/step
# Epoch 49/100
# 5/5 - 1s - loss: 0.0163 - val_loss: 19.4692 - 571ms/epoch - 114ms/step
# Epoch 50/100
# 5/5 - 1s - loss: 0.0156 - val_loss: 19.4202 - 570ms/epoch - 114ms/step
# Epoch 51/100
# 5/5 - 1s - loss: 0.0154 - val_loss: 19.3849 - 574ms/epoch - 115ms/step
# Epoch 52/100
# 5/5 - 1s - loss: 0.0153 - val_loss: 19.3813 - 568ms/epoch - 114ms/step
# Epoch 53/100
# 5/5 - 1s - loss: 0.0155 - val_loss: 19.2982 - 569ms/epoch - 114ms/step
# Epoch 54/100
# 5/5 - 1s - loss: 0.0152 - val_loss: 19.2869 - 572ms/epoch - 114ms/step
# Epoch 55/100
# 5/5 - 1s - loss: 0.0153 - val_loss: 19.3936 - 573ms/epoch - 115ms/step
# Epoch 56/100
# 5/5 - 1s - loss: 0.0150 - val_loss: 19.4416 - 568ms/epoch - 114ms/step
# Epoch 57/100
# 5/5 - 1s - loss: 0.0153 - val_loss: 19.3522 - 568ms/epoch - 114ms/step
# Epoch 58/100
# 5/5 - 1s - loss: 0.0149 - val_loss: 19.3576 - 568ms/epoch - 114ms/step
# Epoch 59/100
# 5/5 - 1s - loss: 0.0146 - val_loss: 19.4325 - 594ms/epoch - 119ms/step
# Epoch 60/100
# 5/5 - 1s - loss: 0.0148 - val_loss: 19.3738 - 705ms/epoch - 141ms/step
# Epoch 61/100
# 5/5 - 1s - loss: 0.0147 - val_loss: 19.2078 - 761ms/epoch - 152ms/step
# Epoch 62/100
# 5/5 - 1s - loss: 0.0153 - val_loss: 19.4260 - 584ms/epoch - 117ms/step
# Epoch 63/100
# 5/5 - 1s - loss: 0.0153 - val_loss: 19.6338 - 572ms/epoch - 114ms/step
# Epoch 64/100
# 5/5 - 1s - loss: 0.0163 - val_loss: 19.5274 - 568ms/epoch - 114ms/step
# Epoch 65/100
# 5/5 - 1s - loss: 0.0143 - val_loss: 19.4313 - 575ms/epoch - 115ms/step
# Epoch 66/100
# 5/5 - 1s - loss: 0.0140 - val_loss: 19.3810 - 577ms/epoch - 115ms/step
# Epoch 67/100
# 5/5 - 1s - loss: 0.0136 - val_loss: 19.2948 - 602ms/epoch - 120ms/step
# Epoch 68/100
# 5/5 - 1s - loss: 0.0141 - val_loss: 19.3512 - 598ms/epoch - 120ms/step
# Epoch 69/100
# 5/5 - 1s - loss: 0.0133 - val_loss: 19.5057 - 568ms/epoch - 114ms/step
# Epoch 70/100
# 5/5 - 1s - loss: 0.0131 - val_loss: 19.5502 - 569ms/epoch - 114ms/step
# Epoch 71/100
# 5/5 - 1s - loss: 0.0138 - val_loss: 19.5989 - 594ms/epoch - 119ms/step
# Epoch 72/100
# 5/5 - 1s - loss: 0.0126 - val_loss: 19.5840 - 564ms/epoch - 113ms/step
# Epoch 73/100
# 5/5 - 1s - loss: 0.0127 - val_loss: 19.4363 - 561ms/epoch - 112ms/step
# Epoch 74/100
# 5/5 - 1s - loss: 0.0125 - val_loss: 19.4047 - 570ms/epoch - 114ms/step
# Epoch 75/100
# 5/5 - 1s - loss: 0.0129 - val_loss: 19.5505 - 587ms/epoch - 117ms/step
# Epoch 76/100
# 5/5 - 1s - loss: 0.0126 - val_loss: 19.4842 - 570ms/epoch - 114ms/step
# Epoch 77/100
# 5/5 - 1s - loss: 0.0123 - val_loss: 19.3627 - 567ms/epoch - 113ms/step
# Epoch 78/100
# 5/5 - 1s - loss: 0.0124 - val_loss: 19.4320 - 569ms/epoch - 114ms/step
# Epoch 79/100
# 5/5 - 1s - loss: 0.0124 - val_loss: 19.5284 - 570ms/epoch - 114ms/step
# Epoch 80/100
# 5/5 - 1s - loss: 0.0126 - val_loss: 19.5810 - 728ms/epoch - 146ms/step
# Epoch 81/100
# 5/5 - 1s - loss: 0.0121 - val_loss: 19.5550 - 572ms/epoch - 114ms/step
# Epoch 82/100
# 5/5 - 1s - loss: 0.0124 - val_loss: 19.4918 - 573ms/epoch - 115ms/step
# Epoch 83/100
# 5/5 - 1s - loss: 0.0118 - val_loss: 19.4208 - 569ms/epoch - 114ms/step
# Epoch 84/100
# 5/5 - 1s - loss: 0.0117 - val_loss: 19.4464 - 566ms/epoch - 113ms/step
# Epoch 85/100
# 5/5 - 1s - loss: 0.0110 - val_loss: 19.4586 - 563ms/epoch - 113ms/step
# Epoch 86/100
# 5/5 - 1s - loss: 0.0115 - val_loss: 19.4519 - 597ms/epoch - 119ms/step
# Epoch 87/100
# 5/5 - 1s - loss: 0.0114 - val_loss: 19.4671 - 618ms/epoch - 124ms/step
# Epoch 88/100
# 5/5 - 1s - loss: 0.0108 - val_loss: 19.4711 - 625ms/epoch - 125ms/step
# Epoch 89/100
# 5/5 - 1s - loss: 0.0112 - val_loss: 19.2349 - 583ms/epoch - 117ms/step
# Epoch 90/100
# 5/5 - 1s - loss: 0.0134 - val_loss: 19.3147 - 563ms/epoch - 113ms/step
# Epoch 91/100
# 5/5 - 1s - loss: 0.0108 - val_loss: 19.4433 - 572ms/epoch - 114ms/step
# Epoch 92/100
# 5/5 - 1s - loss: 0.0111 - val_loss: 19.4493 - 565ms/epoch - 113ms/step
# Epoch 93/100
# 5/5 - 1s - loss: 0.0109 - val_loss: 19.2848 - 567ms/epoch - 113ms/step
# Epoch 94/100
# 5/5 - 1s - loss: 0.0119 - val_loss: 19.3459 - 571ms/epoch - 114ms/step
# Epoch 95/100
# 5/5 - 1s - loss: 0.0103 - val_loss: 19.3190 - 634ms/epoch - 127ms/step
# Epoch 96/100
# 5/5 - 1s - loss: 0.0099 - val_loss: 19.4358 - 578ms/epoch - 116ms/step
# Epoch 97/100
# 5/5 - 1s - loss: 0.0109 - val_loss: 19.5322 - 625ms/epoch - 125ms/step
# Epoch 98/100
# 5/5 - 1s - loss: 0.0121 - val_loss: 19.3847 - 571ms/epoch - 114ms/step
# Epoch 99/100
# 5/5 - 1s - loss: 0.0103 - val_loss: 19.2291 - 565ms/epoch - 113ms/step
# Epoch 100/100
# 5/5 - 1s - loss: 0.0108 - val_loss: 19.1484 - 565ms/epoch - 113ms/step
# 1/1 [==============================] - 1s 1s/step
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /var/folders/j9/qhmtvh7x7078vxjxd4t6fnh80000gn/T/tmpujhbvqst/model/data/model/assets
# INFO:tensorflow:Assets written to: /var/folders/j9/qhmtvh7x7078vxjxd4t6fnh80000gn/T/tmpujhbvqst/model/data/model/assets
# 2023/02/25 13:39:07 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/nikhileshwaravs/opt/anaconda3/lib/python3.9/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils."
# 2023/02/25 13:39:07 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /var/folders/j9/qhmtvh7x7078vxjxd4t6fnh80000gn/T/tmpugi6ttjz/model/data/model/assets
# INFO:tensorflow:Assets written to: /var/folders/j9/qhmtvh7x7078vxjxd4t6fnh80000gn/T/tmpugi6ttjz/model/data/model/assets
# 2/2 [==============================] - 0s 27ms/step
# /var/folders/j9/qhmtvh7x7078vxjxd4t6fnh80000gn/T/ipykernel_10277/1453867266.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predicted_en
# Mean Absolute error is 2.501974299717987
# MAPE is 1837.6222665023768
# RMSE is 3.569336725810101

# %%
#MAE
n=mean_absolute_error(valid.ptl_Con, valid["Predictions"])
print("Mean Absolute error is",n)
# Out:
# Mean Absolute error is 2.501974299717987

# %%
#MAPE
k=np.mean(np.abs((valid.ptl_Con - valid["Predictions"]) / valid.ptl_Con)) * 100
print("MAPE is",k)
# Out:
# MAPE is 1837.6222665023768

# %%
#RMSE
r=math.sqrt(mean_squared_error(valid.ptl_Con, valid["Predictions"]))
print("RMSE is",r)
# Out:
# RMSE is 3.569336725810101
